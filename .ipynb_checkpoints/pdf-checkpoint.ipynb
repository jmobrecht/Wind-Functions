# %%
import numpy as np

def pdf(k,c,x):
    # Note c is not mean wind speed.
    pdf = (k/c)*(x/c)**(k-1)*np.exp(-x/c)**k
    return pdf

# %%
import matplotlib.pyplot as plt
v = np.arange(0,26,0.1)
plt.plot(v,pdf(2,8.5,v))
